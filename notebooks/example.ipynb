# %%
import logging
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils.extmath import randomized_svd
from matplotlib_scalebar.scalebar import ScaleBar

from roispy2 import ROIs

# %%
expmeta = {
    'experimenter': 'Ran',
    'expdate': '20180329',
    'expnum': '1',
    'rootdir': '/gpfs01/euler/data/Data',
    'tempdir': '../IMT_Data',
    'unit': 'um',
    'stimulus_path': '/gpfs01/euler/data/Resources/Stimulus/',
}

c = ROIs(expmeta)
# Out:
# INFO:root:  Root Dir:
# 		/gpfs01/euler/data/Data
# INFO:root:  Imaging Data Dir:
# 		/gpfs01/euler/data/Data/Ran/20180329/1/Pre/
#
# INFO:root:  Morph Data Dir:
# 		/gpfs01/euler/data/Data/Ran/20180329/1/Raw/
#
# INFO:root:  stack_h5_path:
# 		SMP_C1__Stack_.h5
#
# INFO:root:  soma_noise_h5_path:
# 		None
#
# INFO:root:  soma_chirp_h5_path:
# 		None
#
# INFO:root:  soma_lchirp_h5_path:
# 		None
#
# INFO:root:  noise_h5:
# INFO:root:  	0: SMP_C1_d1_DnoiseGC30.h5
# INFO:root:  	1: SMP_C1_d2_DnoiseGC30.h5
# INFO:root:  chirp_h5:
# INFO:root:  	0: SMP_C1_d1_Chirp.h5
# INFO:root:  	1: SMP_C1_d2_Chirp.h5
# INFO:root:  lchirp_h5:
# INFO:root:  	0: SMP_C1_d1_lChirp.h5
# INFO:root:  	1: SMP_C1_d2_lChirp.h5
# INFO:root:  swc_path:
# 		wDataCh0-exported-000.swc
#
# INFO:root:  headerfile_path:
# 		20180329__left.ini
#
# INFO:root:  Finished reading data paths.
#
# INFO:root:  loading stack.h5
#
# INFO:root:  loading noise stimulus
#
# INFO:root:  loading chirp stimulus
#
# ...

# %%
c.check(savefig=True)
# Out:
# INFO:root:  Reading d1
# INFO:root:  Reading d2

# %%
c.finetune(2, offset=[0, 0], pad_more=10, confirm=True, savefig=True)
# Out:
# INFO:root:  Reading d2
# INFO:root:  The ROI coordinates have been adjusted!

# %%
c.calibrate()
# Out:
# INFO:root:  loading all recording data into `df_data`.
#
# INFO:root:  SMP_C1_d1_DnoiseGC30.h5
# INFO:root:  SMP_C1_d2_DnoiseGC30.h5

# %%
fig_rois, ax_rois = c.plot_rois()

# %%
c.get_df_sta(df=[7,9,7], num_iters=0, lambd=0.05, verbal=1000)
# Out:
# INFO:root:  Calculating RF.
# INFO:root:  RF data acquired from Setup 3.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7edeb490030e> in <module>
# ----> 1 c.get_df_sta(df=[7,9,7], num_iters=0, lambd=0.05, verbal=1000)
#
# ~/rgc_dendrites_wip/roisPy2/roispy2/_rois.py in get_df_sta(self, rf_pixel_size, df, num_iters, lambd, verbal)
#     824
#     825             rf_opt = df_data[noise_columns].apply(
# --> 826                 lambda x: get_sta(*x, stimulus=self.stimulus_noise, df=df, num_iters=num_iters, lambd=lambd, verbal=verbal), axis=1)
#     827             df_sta['w'] = rf_opt.apply(lambda x:x[2])
#     828             df_sta['sRF'] = rf_opt.apply(lambda x:x[0])
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# ...

# %%
c.draw_contours()
# Out:
# Finished threshold 60...
# Finished threshold 65...
# Finished threshold 70...

# %%
# c.set_cntr_quality_to_true([0])
# c.set_cntr_quality_to_false([30])

# %%
c.plot_all_rfs(kind='sRF_upsampled')
# Out:
# [<Figure size 595.44x841.68 with 24 Axes>]

# %%
fig_cntr, ax_cntr = c.plot_cntr()

# %%
c.plot_distance()
# Out:
# (<Figure size 595.44x198.48 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fdef65827b8>,
# ...
#        dtype=object))

# %%
c.plot_offset()
# Out:
# (<Figure size 595.44x841.68 with 6 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fdef606f3c8>,
# ...
#        dtype=object))

# %%
c.pairwise()
# Out:
# Start calculating pairwise data for contour level 60
#
#   171 pairs of ROIs are being processing.
#
#  (0000/0171) Processing pair (1 2)...
#  (0017/0171) Processing pair (1 19)...
#  (0034/0171) Processing pair (2 19)...
#  (0051/0171) Processing pair (4 5)...
#  (0068/0171) Processing pair (5 8)...
#  (0085/0171) Processing pair (6 12)...
#  (0102/0171) Processing pair (7 17)...
#  (0119/0171) Processing pair (9 13)...
#  (0136/0171) Processing pair (11 13)...
#  (0153/0171) Processing pair (13 17)...
#  (0170/0171) Processing pair (18 19)...
#   Done.
#
#
# Start calculating pairwise data for contour level 65
#
#   171 pairs of ROIs are being processing.
#
#  (0000/0171) Processing pair (1 2)...
#  (0017/0171) Processing pair (1 19)...
#  (0034/0171) Processing pair (2 19)...
#  (0051/0171) Processing pair (4 5)...
#  (0068/0171) Processing pair (5 8)...
#  (0085/0171) Processing pair (6 12)...
#  (0102/0171) Processing pair (7 17)...
#  (0119/0171) Processing pair (9 13)...
# ...

# %%
c.plot_hexbin()
# Out:
# (<Figure size 595.44x198.48 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fdef5e2fe48>,
# ...
#        dtype=object))
