# %%
import logging
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils.extmath import randomized_svd
from matplotlib_scalebar.scalebar import ScaleBar

from roispy2 import ROIs

# %%
expmeta = {
    'experimenter': 'Ran',
    'expdate': '20180329',
    'expnum': '1',
    'rootdir': '/gpfs01/euler/data/Data',
    'tempdir': '../IMT_Data',
    'unit': 'um',
    'stimulus_path': '/gpfs01/euler/data/Resources/Stimulus/',
}

c = ROIs(expmeta)
# Out:
# INFO:root:  loading saved data.

# %%
c.check(savefig=True)
# Out:
# INFO:root:  Reading d01
# INFO:root:  Reading d02
# INFO:root:  Reading d03
# INFO:root:  Reading d04
# INFO:root:  Reading d05
# INFO:root:  Reading d06
# INFO:root:  Reading d07
# INFO:root:  Reading d08
# INFO:root:  Reading d09
# INFO:root:  Reading d10
# INFO:root:  Reading d11
# INFO:root:  Reading d12
# INFO:root:  Reading d13
# INFO:root:  Reading d14
# INFO:root:  Reading d15

# %%
c.finetune(2, offset=[0, 0], pad_more=10, confirm=True, savefig=True)
# Out:
# INFO:root:  Reading d02
# INFO:root:  The ROI coordinates have been adjusted!

# %%
c.calibrate()
# Out:
# INFO:root:  loading all recording data into `df_data`.
#
# INFO:root:  SMP_C4_d01_DnoiseGC30.h5
# INFO:root:  SMP_C4_d02_DnoiseGC30.h5
# INFO:root:  SMP_C4_d03_DnoiseGC30.h5
# INFO:root:  SMP_C4_d04_DnoiseGC30.h5
# INFO:root:  SMP_C4_d05_DnoiseGC30.h5
# INFO:root:  SMP_C4_d06_DnoiseGC30.h5
# INFO:root:  SMP_C4_d07_DnoiseGC30.h5
# INFO:root:  SMP_C4_d08_DnoiseGC30.h5
# INFO:root:  SMP_C4_d09_DnoiseGC30.h5
# INFO:root:  SMP_C4_d10_DnoiseGC30.h5
# INFO:root:  SMP_C4_d11_DnoiseGC30.h5
# INFO:root:  SMP_C4_d12_DnoiseGC30.h5
# INFO:root:  SMP_C4_d13_DnoiseGC30.h5
# INFO:root:  SMP_C4_d14_DnoiseGC30.h5
# INFO:root:  SMP_C4_d15_DnoiseGC30.h5

# %%
fig_rois, ax_rois = c.plot_rois()

# %%
from roispy2._utils import load_h5_data
c.stimulus_noise = load_h5_data(expmeta['stimulus_path'] + '/old/noise.h5')['k'].T
c.get_df_sta(df=[7,9,7], num_iters=0, lambd=0.05, verbal=1000)
# Out:
# INFO:root:  Calculating RF.
# INFO:root:  RF data acquired from Setup 2: need to be flipped.
#
# /usr/local/lib/python3.6/dist-packages/jax/lib/xla_bridge.py:119: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-cef54c0b7d43> in <module>
#       1 from roispy2._utils import load_h5_data
#       2 c.stimulus_noise = load_h5_data(expmeta['stimulus_path'] + '/old/noise.h5')['k'].T
# ----> 3 c.get_df_sta(df=[7,9,7], num_iters=0, lambd=0.05, verbal=1000)
#
# ~/rgc_dendrites_wip/roisPy2/roispy2/_rois.py in get_df_sta(self, rf_pixel_size, df, num_iters, lambd, verbal)
#     815
#     816             rf_opt = df_data[noise_columns].apply(
# --> 817                 lambda x: get_sta(*x, stimulus=self.stimulus_noise, df=df, num_iters=num_iters, lambd=lambd, verbal=verbal), axis=1)
#     818             df_sta['w'] = rf_opt.apply(lambda x:x[2])
#     819             df_sta['sRF'] = rf_opt.apply(lambda x:np.fliplr(x[0]))
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# ~/rgc_dendrites_wip/roisPy2/roispy2/_rois.py in <lambda>(x)
#     815
#     816             rf_opt = df_data[noise_columns].apply(
# --> 817                 lambda x: get_sta(*x, stimulus=self.stimulus_noise, df=df, num_iters=num_iters, lambd=lambd, verbal=verbal), axis=1)
#     818             df_sta['w'] = rf_opt.apply(lambda x:x[2])
#     819             df_sta['sRF'] = rf_opt.apply(lambda x:np.fliplr(x[0]))
#
# ~/rgc_dendrites_wip/roisPy2/roispy2/_sta.py in get_sta(stimulus, df, num_iters, lambd, verbal, *data)
#      59         w = spl.w_spl
#      60
# ---> 61     sRF, tRF = get_spatial_and_temporal_filters(spl.w_spl, dims)
#      62
#      63     return [np.flipud(sRF.T), tRF, w]
#
# ~/rfest/RFEst/rfest/_utils.py in get_spatial_and_temporal_filters(w, dims)
#      83     dims_tRF = dims[0]
#      84     dims_sRF = dims[1:]
# ---> 85     U, S, Vt = randomized_svd(w.reshape(dims_tRF, np.prod(dims_sRF)), 3)
#      86     sRF = Vt[0].reshape(*dims_sRF)
#      87     tRF = U[:, 0]
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/extmath.py in randomized_svd(M, n_components, n_oversamples, n_iter, power_iteration_normalizer, transpose, flip_sign, random_state)
#     346
#     347     Q = randomized_range_finder(M, n_random, n_iter,
# --> 348                                 power_iteration_normalizer, random_state)
#     349
#     350     # project M to the (k + p) dimensional space using the basis vectors
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/extmath.py in randomized_range_finder(A, size, n_iter, power_iteration_normalizer, random_state)
#     230             Q = safe_sparse_dot(A.T, Q)
#     231         elif power_iteration_normalizer == 'LU':
# --> 232             Q, _ = linalg.lu(safe_sparse_dot(A, Q), permute_l=True)
#     233             Q, _ = linalg.lu(safe_sparse_dot(A.T, Q), permute_l=True)
#     234         elif power_iteration_normalizer == 'QR':
#
# /usr/local/lib/python3.6/dist-packages/scipy/linalg/decomp_lu.py in lu(a, permute_l, overwrite_a, check_finite)
#     208     """
#     209     if check_finite:
# --> 210         a1 = asarray_chkfinite(a)
#     211     else:
#     212         a1 = asarray(a)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     494
#     495     """
# --> 496     a = asarray(a, dtype=dtype, order=order)
#     497     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     498         raise ValueError(
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /usr/local/lib/python3.6/dist-packages/jax/interpreters/xla.py in __array__(self, dtype, context)
#     831
#     832   def __array__(self, dtype=None, context=None):
# --> 833     return onp.asarray(self._value, dtype=dtype)
#     834
#     835   __str__ = partialmethod(_forward_to_value, str)
#
# /usr/local/lib/python3.6/dist-packages/jax/interpreters/xla.py in _value(self)
#     736         self._npy_value = lazy.eval_lexpr(self._lazy_expr, None)
#     737       else:
# --> 738         self._npy_value = _force(self).device_buffer.to_py()
#     739       self._npy_value.flags.writeable = False
#     740     return self._npy_value
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_internal.py in _dtype_from_pep3118(spec)
#     561
#     562
# --> 563 def _dtype_from_pep3118(spec):
#     564     stream = _Stream(spec)
#     565     dtype, align = __dtype_from_pep3118(stream, is_subdtype=False)
#
# KeyboardInterrupt:

# %%
c.plot_all_rfs(kind='sRF_upsampled')

# %%
c.draw_contours()
fig_cntr, ax_cntr = c.plot_cntr()
